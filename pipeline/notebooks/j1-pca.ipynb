# %%
# %%capture
# Prepare
import os
os.chdir('/Users/denis/Documents/Projects/cmap/cmap-l1000-analysis')
# %load_ext rpy2.ipython
# %R source('/Users/denis/Documents/Projects/scripts/Support.R')

# %% [markdown]
# ### Infile

# %%
# %%R
# # Get infile
# infiles <- c('f2-pca.dir/cmap_l1000-pca.rda', 'f1-processed_data.dir/cmap_l1000-sample_annotations.txt')

# %%
# %%R
# # Load PCA data
# load(infiles[1])
#
# # Read annotations
# sampleAnnotationDataframe <- read.table(infiles[2], sep='\t', header=TRUE, row.names='sample_id')

# %% [markdown]
# ### Computation

# %%
# %%R
# # Get legend
# colorLegend <- getLegend(rownames(sampleAnnotationDataframe), sampleAnnotationDataframe$cell_id) # det_plate

# %%
# %%R
# # Get PCs
# PCs <- c('PC2', 'PC1')
#
# # Plot PCA
# plot(pca$x[,PCs],
#      xlab = pca$varLabels[PCs[1]],
#      ylab = pca$varLabels[PCs[2]],
#      main = 'PCA Plot of L1000 Data',
#      col=colorLegend$colors)
#
# # Plot legend
# legend('bottomleft', fill=colorLegend$legend, legend=names(colorLegend$legend), title='Cell Type')
